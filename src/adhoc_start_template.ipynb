# %%
import numpy as np
import pandas as pd

pd.options.display.max_columns = None
pd.options.display.max_rows = None

from matplotlib import pyplot as plt
import seaborn as sns

CR_COLOR = "#0079FF"

# %%
df_2022 = pd.read_csv("../data/2022-23_reg_season_clean.csv")
df_2023 = pd.read_csv("../data/2023-24_reg_season_clean.csv")


# main df
# df = df_2022.copy()
df = df_2023.copy()

# convert to date type
df["game_time"] = pd.to_datetime(df["game_time"])
df["date"] = pd.to_datetime(df["date"])

print(df_2022.shape)
print(df_2023.shape)
df.head()
# Out:
# (2460, 70)
# (2400, 70)
#             team                opponent day_of_week       date Start (ET)  \
# 0  Atlanta Hawks       Charlotte Hornets         Wed 2023-10-25      7:00p
# 1  Atlanta Hawks         New York Knicks         Fri 2023-10-27      7:30p
# 2  Atlanta Hawks         Milwaukee Bucks         Sun 2023-10-29      7:00p
# 3  Atlanta Hawks  Minnesota Timberwolves         Mon 2023-10-30      7:30p
# 4  Atlanta Hawks      Washington Wizards         Wed 2023-11-01      7:30p
#
#    season_start_year  is_playoff  is_home_game           game_time  \
# 0               2023           0             0 2023-10-25 19:00:00
# 1               2023           0             1 2023-10-27 19:30:00
# 2               2023           0             0 2023-10-29 19:00:00
# 3               2023           0             1 2023-10-30 19:30:00
# 4               2023           0             1 2023-11-01 19:30:00
#
#    city_team_key abbreviation          timezone  time_diff_from_et  elevation  \
# 0  Atlanta Hawks          ATL  America/New_York                  0       1023
# 1  Atlanta Hawks          ATL  America/New_York                  0       1023
# 2  Atlanta Hawks          ATL  America/New_York                  0       1023
# 3  Atlanta Hawks          ATL  America/New_York                  0       1023
# 4  Atlanta Hawks          ATL  America/New_York                  0       1023
#
#    Latitude  Longitude  city_team_key_opponent abbreviation_opponent  \
# 0    33.757     84.396       Charlotte Hornets                   CHA
# 1    33.757     84.396         New York Knicks                   NYK
# 2    33.757     84.396         Milwaukee Bucks                   MIL
# 3    33.757     84.396  Minnesota Timberwolves                   MIN
# 4    33.757     84.396      Washington Wizards                   WAS
#
#   timezone_opponent  time_diff_from_et_opponent  elevation_opponent  \
# 0  America/New_York                           0                 721
# 1  America/New_York                           0                  35
# 2   America/Chicago                          -1                 593
# 3   America/Chicago                          -1                 845
# 4  America/New_York                           0                  46
#
#    Latitude_opponent  Longitude_opponent  is_covid_bubble  \
# 0             35.225              80.839                0
# 1             40.751              73.993                0
# 2             43.045              87.917                0
# 3             44.980              93.276                0
# 4             38.898              77.021                0
#
#    is_pre_nba_cup_knockout  is_post_nba_cup  game_time_diff_from_et  game_lat  \
# 0                        1                0                       0    35.225
# 1                        1                0                       0    33.757
# 2                        1                0                      -1    43.045
# 3                        1                0                       0    33.757
# 4                        1                0                       0    33.757
#
#    game_lon  game_elevation home_team_abbr away_team_abbr             game_id  \
# 0    80.839             721            CHA            ATL  ATL@CHA_2023-10-25
# 1    84.396            1023            ATL            NYK  NYK@ATL_2023-10-27
# 2    87.917             593            MIL            ATL  ATL@MIL_2023-10-29
# 3    84.396            1023            ATL            MIN  MIN@ATL_2023-10-30
# 4    84.396            1023            ATL            WAS  WAS@ATL_2023-11-01
#
#    time_since_prev_game  is_last_game_home  is_2_games_ago_home  \
# 0                  -1.0                  1                    1
# 1                  48.5                  0                    1
# 2                  47.5                  1                    0
# 3                  24.5                  0                    1
# 4                  48.0                  1                    0
#
#    is_3_games_ago_home  is_4_games_ago_home  is_5_games_ago_home  \
# 0                    1                    1                    1
# 1                    1                    1                    1
# 2                    1                    1                    1
# 3                    0                    1                    1
# 4                    1                    0                    1
#
#    is_6_games_ago_home  is_7_games_ago_home  num_away_last_5_games  \
# 0                    1                    1                      0
# 1                    1                    1                      1
# 2                    1                    1                      1
# 3                    1                    1                      2
# 4                    1                    1                      2
#
#    start_of_streak  streak_id  streak_counter  incoming_away_game_streak  \
# 0             True          1               1                          0
# 1             True          2               1                          0
# 2             True          3               1                          0
# 3             True          4               1                          0
# 4            False          4               2                          0
#
#    days_since_1_games_ago  days_since_2_games_ago  days_since_3_games_ago  \
# 0                   150.0                   150.0                   150.0
# 1                     2.0                   150.0                   150.0
# 2                     2.0                     4.0                   150.0
# 3                     1.0                     3.0                     5.0
# 4                     2.0                     3.0                     5.0
#
#    days_since_4_games_ago  days_since_5_games_ago  days_since_6_games_ago  \
# 0                   150.0                   150.0                   150.0
# 1                   150.0                   150.0                   150.0
# 2                   150.0                   150.0                   150.0
# 3                   150.0                   150.0                   150.0
# 4                     7.0                   150.0                   150.0
#
#    days_since_7_games_ago  num_games_last_4_days  num_games_last_7_days  \
# 0                   150.0                      0                      0
# 1                   150.0                      1                      1
# 2                   150.0                      2                      2
# 3                   150.0                      2                      3
# 4                   150.0                      2                      4
#
#    prev_game_lon  prev_game_lat  distance_from_previous_game  \
# 0         84.396         33.757                   226.016193
# 1         80.839         35.225                   226.016193
# 2         84.396         33.757                   667.804853
# 3         87.917         43.045                   667.804853
# 4         84.396         33.757                     0.000000
#
#    cumulative_distance  is_back_to_back           team_opponent  \
# 0           226.016193                0       Charlotte Hornets
# 1           452.032386                0         New York Knicks
# 2           667.804853                0         Milwaukee Bucks
# 3          1335.609706                1  Minnesota Timberwolves
# 4             0.000000                0      Washington Wizards
#
#   abbreviation_opponent.1  time_since_prev_game_opponent  \
# 0                     CHA                           -1.0
# 1                     NYK                           48.5
# 2                     MIL                           71.5
# 3                     MIN                           47.5
# 4                     WAS                           48.5
#
#    num_games_last_7_days_opponent  distance_from_previous_game_opponent  \
# 0                               0                              0.000000
# 1                               1                            746.273513
# 2                               1                              0.000000
# 3                               2                            905.694219
# 4                               3                            541.319182
#
#    cumulative_distance_opponent  hours_of_rest_difference  games_last_7_diff  \
# 0                      0.000000                       0.0                  0
# 1                    746.273513                       0.0                  0
# 2                      0.000000                     -24.0                  1
# 3                    905.694219                     -23.0                  1
# 4                    541.319182                      -0.5                  1
#
#    prev_game_distance_diff  cumulative_distance_diff
# 0               226.016193                226.016193
# 1              -520.257320               -294.241127
# 2               667.804853                667.804853
# 3              -237.889366                429.915487
# 4              -541.319182               -541.319182

# %%
# mark the week of season
df['week_number'] = df['date'].dt.isocalendar().week
df['week_of_season'] = np.where(df['week_number'] >= 43, df['week_number'] - 42, df['week_number'] + 1 +(df['week_number'].max() - df['week_number'][0]))

df['team_game_id'] = df.groupby('abbreviation').cumcount() + 1
df.head()
# Out:
#             team                opponent day_of_week       date Start (ET)  \
# 0  Atlanta Hawks       Charlotte Hornets         Wed 2023-10-25      7:00p
# 1  Atlanta Hawks         New York Knicks         Fri 2023-10-27      7:30p
# 2  Atlanta Hawks         Milwaukee Bucks         Sun 2023-10-29      7:00p
# 3  Atlanta Hawks  Minnesota Timberwolves         Mon 2023-10-30      7:30p
# 4  Atlanta Hawks      Washington Wizards         Wed 2023-11-01      7:30p
#
#    season_start_year  is_playoff  is_home_game           game_time  \
# 0               2023           0             0 2023-10-25 19:00:00
# 1               2023           0             1 2023-10-27 19:30:00
# 2               2023           0             0 2023-10-29 19:00:00
# 3               2023           0             1 2023-10-30 19:30:00
# 4               2023           0             1 2023-11-01 19:30:00
#
#    city_team_key abbreviation          timezone  time_diff_from_et  elevation  \
# 0  Atlanta Hawks          ATL  America/New_York                  0       1023
# 1  Atlanta Hawks          ATL  America/New_York                  0       1023
# 2  Atlanta Hawks          ATL  America/New_York                  0       1023
# 3  Atlanta Hawks          ATL  America/New_York                  0       1023
# 4  Atlanta Hawks          ATL  America/New_York                  0       1023
#
#    Latitude  Longitude  city_team_key_opponent abbreviation_opponent  \
# 0    33.757     84.396       Charlotte Hornets                   CHA
# 1    33.757     84.396         New York Knicks                   NYK
# 2    33.757     84.396         Milwaukee Bucks                   MIL
# 3    33.757     84.396  Minnesota Timberwolves                   MIN
# 4    33.757     84.396      Washington Wizards                   WAS
#
#   timezone_opponent  time_diff_from_et_opponent  elevation_opponent  \
# 0  America/New_York                           0                 721
# 1  America/New_York                           0                  35
# 2   America/Chicago                          -1                 593
# 3   America/Chicago                          -1                 845
# 4  America/New_York                           0                  46
#
#    Latitude_opponent  Longitude_opponent  is_covid_bubble  \
# 0             35.225              80.839                0
# 1             40.751              73.993                0
# 2             43.045              87.917                0
# 3             44.980              93.276                0
# 4             38.898              77.021                0
#
#    is_pre_nba_cup_knockout  is_post_nba_cup  game_time_diff_from_et  game_lat  \
# 0                        1                0                       0    35.225
# 1                        1                0                       0    33.757
# 2                        1                0                      -1    43.045
# 3                        1                0                       0    33.757
# 4                        1                0                       0    33.757
#
#    game_lon  game_elevation home_team_abbr away_team_abbr             game_id  \
# 0    80.839             721            CHA            ATL  ATL@CHA_2023-10-25
# 1    84.396            1023            ATL            NYK  NYK@ATL_2023-10-27
# 2    87.917             593            MIL            ATL  ATL@MIL_2023-10-29
# 3    84.396            1023            ATL            MIN  MIN@ATL_2023-10-30
# 4    84.396            1023            ATL            WAS  WAS@ATL_2023-11-01
#
#    time_since_prev_game  is_last_game_home  is_2_games_ago_home  \
# 0                  -1.0                  1                    1
# 1                  48.5                  0                    1
# 2                  47.5                  1                    0
# 3                  24.5                  0                    1
# 4                  48.0                  1                    0
#
#    is_3_games_ago_home  is_4_games_ago_home  is_5_games_ago_home  \
# 0                    1                    1                    1
# 1                    1                    1                    1
# 2                    1                    1                    1
# 3                    0                    1                    1
# 4                    1                    0                    1
#
#    is_6_games_ago_home  is_7_games_ago_home  num_away_last_5_games  \
# 0                    1                    1                      0
# 1                    1                    1                      1
# 2                    1                    1                      1
# 3                    1                    1                      2
# 4                    1                    1                      2
#
#    start_of_streak  streak_id  streak_counter  incoming_away_game_streak  \
# 0             True          1               1                          0
# 1             True          2               1                          0
# 2             True          3               1                          0
# 3             True          4               1                          0
# 4            False          4               2                          0
#
#    days_since_1_games_ago  days_since_2_games_ago  days_since_3_games_ago  \
# 0                   150.0                   150.0                   150.0
# 1                     2.0                   150.0                   150.0
# 2                     2.0                     4.0                   150.0
# 3                     1.0                     3.0                     5.0
# 4                     2.0                     3.0                     5.0
#
#    days_since_4_games_ago  days_since_5_games_ago  days_since_6_games_ago  \
# 0                   150.0                   150.0                   150.0
# 1                   150.0                   150.0                   150.0
# 2                   150.0                   150.0                   150.0
# 3                   150.0                   150.0                   150.0
# 4                     7.0                   150.0                   150.0
#
#    days_since_7_games_ago  num_games_last_4_days  num_games_last_7_days  \
# 0                   150.0                      0                      0
# 1                   150.0                      1                      1
# 2                   150.0                      2                      2
# 3                   150.0                      2                      3
# 4                   150.0                      2                      4
#
#    prev_game_lon  prev_game_lat  distance_from_previous_game  \
# 0         84.396         33.757                   226.016193
# 1         80.839         35.225                   226.016193
# 2         84.396         33.757                   667.804853
# 3         87.917         43.045                   667.804853
# 4         84.396         33.757                     0.000000
#
#    cumulative_distance  is_back_to_back           team_opponent  \
# 0           226.016193                0       Charlotte Hornets
# 1           452.032386                0         New York Knicks
# 2           667.804853                0         Milwaukee Bucks
# 3          1335.609706                1  Minnesota Timberwolves
# 4             0.000000                0      Washington Wizards
#
#   abbreviation_opponent.1  time_since_prev_game_opponent  \
# 0                     CHA                           -1.0
# 1                     NYK                           48.5
# 2                     MIL                           71.5
# 3                     MIN                           47.5
# 4                     WAS                           48.5
#
#    num_games_last_7_days_opponent  distance_from_previous_game_opponent  \
# 0                               0                              0.000000
# 1                               1                            746.273513
# 2                               1                              0.000000
# 3                               2                            905.694219
# 4                               3                            541.319182
#
#    cumulative_distance_opponent  hours_of_rest_difference  games_last_7_diff  \
# 0                      0.000000                       0.0                  0
# 1                    746.273513                       0.0                  0
# 2                      0.000000                     -24.0                  1
# 3                    905.694219                     -23.0                  1
# 4                    541.319182                      -0.5                  1
#
#    prev_game_distance_diff  cumulative_distance_diff  week_number  \
# 0               226.016193                226.016193           43
# 1              -520.257320               -294.241127           43
# 2               667.804853                667.804853           43
# 3              -237.889366                429.915487           44
# 4              -541.319182               -541.319182           44
#
#   week_of_season  team_game_id
# 0              1             1
# 1              1             2
# 2              1             3
# 3              2             4
# 4              2             5

# %%
# mark the first game after the 12/2
# after_cup_dict = df[df['date'].gt("2023-12-15")].groupby('team_name').first()['team_game_id'].to_dict()
# after_cup_dict

after_cup_dict = df[df['date'].gt("2023-12-02")].groupby('abbreviation').first()['team_game_id'].to_dict()
# after_cup_dict

df['after_id'] = df['abbreviation'].map(after_cup_dict)
df['is_first_after_cup'] = np.where(df['team_game_id'] == df['after_id'], 1, 0)
# df['distance_from_previous_game'] = np.where(df['is_first_after_cup'] == 1, 0, df['distance_from_previous_game'])
# df[['team', 'date', 'team_game_id',"is_home_game", "opponent", 'distance_from_previous_game', 'is_first_after_cup']].head(30)
# Out:
#              team       date  team_game_id  is_home_game  \
# 0   Atlanta Hawks 2023-10-25             1             0
# 1   Atlanta Hawks 2023-10-27             2             1
# 2   Atlanta Hawks 2023-10-29             3             0
# 3   Atlanta Hawks 2023-10-30             4             1
# 4   Atlanta Hawks 2023-11-01             5             1
# 5   Atlanta Hawks 2023-11-04             6             0
# 6   Atlanta Hawks 2023-11-06             7             0
# 7   Atlanta Hawks 2023-11-09             8             0
# 8   Atlanta Hawks 2023-11-11             9             1
# 9   Atlanta Hawks 2023-11-14            10             0
# 10  Atlanta Hawks 2023-11-15            11             1
# 11  Atlanta Hawks 2023-11-17            12             1
# 12  Atlanta Hawks 2023-11-21            13             1
# 13  Atlanta Hawks 2023-11-22            14             1
# 14  Atlanta Hawks 2023-11-25            15             0
# 15  Atlanta Hawks 2023-11-26            16             0
# 16  Atlanta Hawks 2023-11-28            17             0
# 17  Atlanta Hawks 2023-11-30            18             0
# 18  Atlanta Hawks 2023-12-02            19             0
# 19  Atlanta Hawks 2023-12-11            20             1
# 20  Atlanta Hawks 2023-12-13            21             0
# 21  Atlanta Hawks 2023-12-15            22             0
# 22  Atlanta Hawks 2023-12-16            23             0
# 23  Atlanta Hawks 2023-12-18            24             1
# 24  Atlanta Hawks 2023-12-20            25             0
# 25  Atlanta Hawks 2023-12-22            26             0
# 26  Atlanta Hawks 2023-12-23            27             1
# 27  Atlanta Hawks 2023-12-26            28             0
# 28  Atlanta Hawks 2023-12-29            29             1
# 29  Atlanta Hawks 2023-12-31            30             0
#
#                   opponent  distance_from_previous_game  is_first_after_cup
# 0        Charlotte Hornets                   226.016193                   0
# 1          New York Knicks                   226.016193                   0
# 2          Milwaukee Bucks                   667.804853                   0
# 3   Minnesota Timberwolves                   667.804853                   0
# 4       Washington Wizards                     0.000000                   0
# 5     New Orleans Pelicans                   423.875640                   0
# 6    Oklahoma City Thunder                   574.484612                   0
# 7            Orlando Magic                  1055.109677                   0
# 8               Miami Heat                   401.174473                   0
# 9          Detroit Pistons                   596.222902                   0
# 10         New York Knicks                   596.222902                   0
# 11      Philadelphia 76ers                     0.000000                   0
# 12          Indiana Pacers                     0.000000                   0
# 13           Brooklyn Nets                     0.000000                   0
# 14      Washington Wizards                   541.319182                   0
# 15          Boston Celtics                   392.722790                   0
# 16     Cleveland Cavaliers                   547.903098                   0
# 17       San Antonio Spurs                  1251.650956                   0
# 18         Milwaukee Bucks                  1104.135497                   0
# 19          Denver Nuggets                     0.000000                   1
# 20         Toronto Raptors                   732.742992                   0
# 21         Toronto Raptors                     0.000000                   0
# 22     Cleveland Cavaliers                   188.798507                   0
# 23         Detroit Pistons                   553.621492                   0
# 24         Houston Rockets                   699.145047                   0
# 25              Miami Heat                   964.433523                   0
# 26       Memphis Grizzlies                   604.639314                   0
# 27           Chicago Bulls                   587.721323                   0
# 28        Sacramento Kings                   587.721323                   0
# 29      Washington Wizards                   541.319182                   0

# %%
# after_cup_dict

# %%
df.head(3)
# Out:
#             team           opponent day_of_week       date Start (ET)  \
# 0  Atlanta Hawks  Charlotte Hornets         Wed 2023-10-25      7:00p
# 1  Atlanta Hawks    New York Knicks         Fri 2023-10-27      7:30p
# 2  Atlanta Hawks    Milwaukee Bucks         Sun 2023-10-29      7:00p
#
#    season_start_year  is_playoff  is_home_game           game_time  \
# 0               2023           0             0 2023-10-25 19:00:00
# 1               2023           0             1 2023-10-27 19:30:00
# 2               2023           0             0 2023-10-29 19:00:00
#
#    city_team_key abbreviation          timezone  time_diff_from_et  elevation  \
# 0  Atlanta Hawks          ATL  America/New_York                  0       1023
# 1  Atlanta Hawks          ATL  America/New_York                  0       1023
# 2  Atlanta Hawks          ATL  America/New_York                  0       1023
#
#    Latitude  Longitude city_team_key_opponent abbreviation_opponent  \
# 0    33.757     84.396      Charlotte Hornets                   CHA
# 1    33.757     84.396        New York Knicks                   NYK
# 2    33.757     84.396        Milwaukee Bucks                   MIL
#
#   timezone_opponent  time_diff_from_et_opponent  elevation_opponent  \
# 0  America/New_York                           0                 721
# 1  America/New_York                           0                  35
# 2   America/Chicago                          -1                 593
#
#    Latitude_opponent  Longitude_opponent  is_covid_bubble  \
# 0             35.225              80.839                0
# 1             40.751              73.993                0
# 2             43.045              87.917                0
#
#    is_pre_nba_cup_knockout  is_post_nba_cup  game_time_diff_from_et  game_lat  \
# 0                        1                0                       0    35.225
# 1                        1                0                       0    33.757
# 2                        1                0                      -1    43.045
#
#    game_lon  game_elevation home_team_abbr away_team_abbr             game_id  \
# 0    80.839             721            CHA            ATL  ATL@CHA_2023-10-25
# 1    84.396            1023            ATL            NYK  NYK@ATL_2023-10-27
# 2    87.917             593            MIL            ATL  ATL@MIL_2023-10-29
#
#    time_since_prev_game  is_last_game_home  is_2_games_ago_home  \
# 0                  -1.0                  1                    1
# 1                  48.5                  0                    1
# 2                  47.5                  1                    0
#
#    is_3_games_ago_home  is_4_games_ago_home  is_5_games_ago_home  \
# 0                    1                    1                    1
# 1                    1                    1                    1
# 2                    1                    1                    1
#
#    is_6_games_ago_home  is_7_games_ago_home  num_away_last_5_games  \
# 0                    1                    1                      0
# 1                    1                    1                      1
# 2                    1                    1                      1
#
#    start_of_streak  streak_id  streak_counter  incoming_away_game_streak  \
# 0             True          1               1                          0
# 1             True          2               1                          0
# 2             True          3               1                          0
#
#    days_since_1_games_ago  days_since_2_games_ago  days_since_3_games_ago  \
# 0                   150.0                   150.0                   150.0
# 1                     2.0                   150.0                   150.0
# 2                     2.0                     4.0                   150.0
#
#    days_since_4_games_ago  days_since_5_games_ago  days_since_6_games_ago  \
# 0                   150.0                   150.0                   150.0
# 1                   150.0                   150.0                   150.0
# 2                   150.0                   150.0                   150.0
#
#    days_since_7_games_ago  num_games_last_4_days  num_games_last_7_days  \
# 0                   150.0                      0                      0
# 1                   150.0                      1                      1
# 2                   150.0                      2                      2
#
#    prev_game_lon  prev_game_lat  distance_from_previous_game  \
# 0         84.396         33.757                   226.016193
# 1         80.839         35.225                   226.016193
# 2         84.396         33.757                   667.804853
#
#    cumulative_distance  is_back_to_back      team_opponent  \
# 0           226.016193                0  Charlotte Hornets
# 1           452.032386                0    New York Knicks
# 2           667.804853                0    Milwaukee Bucks
#
#   abbreviation_opponent.1  time_since_prev_game_opponent  \
# 0                     CHA                           -1.0
# 1                     NYK                           48.5
# 2                     MIL                           71.5
#
#    num_games_last_7_days_opponent  distance_from_previous_game_opponent  \
# 0                               0                              0.000000
# 1                               1                            746.273513
# 2                               1                              0.000000
#
#    cumulative_distance_opponent  hours_of_rest_difference  games_last_7_diff  \
# 0                      0.000000                       0.0                  0
# 1                    746.273513                       0.0                  0
# 2                      0.000000                     -24.0                  1
#
#    prev_game_distance_diff  cumulative_distance_diff  week_number  \
# 0               226.016193                226.016193           43
# 1              -520.257320               -294.241127           43
# 2               667.804853                667.804853           43
#
#   week_of_season  team_game_id  after_id  is_first_after_cup
# 0              1             1        20                   0
# 1              1             2        20                   0
# 2              1             3        20                   0

# %%
df['is_post_nba_cup'].unique()
# Out:
# array([0, 1])

# %%
# df.columns

# %%
assert False

# %%
# total travel for each team (simple)
piv = df.pivot_table(
    index=["season_start_year","abbreviation", "team"],
    values="distance_from_previous_game",
    aggfunc="sum"
    
).sort_values(by="distance_from_previous_game").reset_index()
piv['team'] = piv['team'].str.split(" ").str[-1]
print(piv.shape)
# piv
# ax = piv.plot(
#     kind="bar",
#     x="abbreviation",
#     legend=False,
#     title="Total Distance traveled by each team for the 2023 Season",
#     ylabel="Miles",
#     xlabel="Team",
#     # grid='y',
#     figsize=(8,4)
# )
# ax.grid(axis="y")
piv.head(2)
# Out:
# (30, 4)
#    season_start_year abbreviation       team  distance_from_previous_game
# 0               2023          CLE  Cavaliers                 31398.561368
# 1               2023          IND     Pacers                 32437.688911
